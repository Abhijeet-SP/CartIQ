# %%
import pandas as pd

# %%
fact_order_timing = pd.read_csv("/Users/abhijeetsinghparihar/Desktop/Projects/Supply Chain Project/CartIQ/data/raw/fact_orders_timing.csv")
fact_order_basket = pd.read_csv("/Users/abhijeetsinghparihar/Desktop/Projects/Supply Chain Project/CartIQ/data/raw/fact_orders_basket.csv")
dim_products = pd.read_csv("/Users/abhijeetsinghparihar/Desktop/Projects/Supply Chain Project/CartIQ/data/raw/dim_products.csv")
dim_departments = pd.read_csv("/Users/abhijeetsinghparihar/Desktop/Projects/Supply Chain Project/CartIQ/data/raw/dim_departments.csv")

# %%
print(fact_order_timing.columns)
print(fact_order_basket.columns)
print(dim_departments.columns)
print(dim_products.columns)
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')
# Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='str')
# Index(['department_id', 'department'], dtype='str')
# Index(['product_id', 'product_name', 'aisle_id', 'department_id'], dtype='str')

# %% [markdown]
# ### Product Recommendation Layer 1
#
# Input: Current Cart + User History + Context (time_of_the_day, add_to_cart_order)

# %%
d1 = fact_order_timing[fact_order_timing['eval_set'] == 'prior'][['order_id', 'user_id', 'order_number', 
                                                                  'order_dow', 'order_hour_of_day', 
                                                                  'days_since_prior_order']]
d1 = d1.merge(fact_order_basket, on="order_id", how='inner') 
print(d1.columns)
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order', 'product_id', 'add_to_cart_order',
#        'reordered'],
#       dtype='str')

# %%
d1 = d1.merge(dim_products, on='product_id', how='inner')
print(d1.columns)
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order', 'product_id', 'add_to_cart_order',
#        'reordered', 'product_name', 'aisle_id', 'department_id'],
#       dtype='str')

# %%
d1 = d1.merge(dim_departments, on='department_id', how='inner')
print(d1.columns)
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order', 'product_id', 'add_to_cart_order',
#        'reordered', 'product_name', 'aisle_id', 'department_id', 'department'],
#       dtype='str')

# %%
d1.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  \
# 0                                     Soda        77              7
# 1  Organic Unsweetened Vanilla Almond Milk        91             16
# 2                      Original Beef Jerky        23             19
# 3               Aged White Cheddar Popcorn        23             19
# 4         XL Pick-A-Size Paper Towel Rolls        54             17
#
#    department
# 0   beverages
# 1  dairy eggs
# 2      snacks
# 3      snacks
# 4   household
