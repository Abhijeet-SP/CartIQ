# %%
import pandas as pd
data = pd.read_csv("/Users/abhijeetsinghparihar/Desktop/Projects/Supply Chain Project/CartIQ/data/raw/orders.csv")

# %%
print(data['order_id'].nunique())
# Out:
# 3421083

# %%
data.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
data_2 = pd.read_csv("/Users/abhijeetsinghparihar/Desktop/Projects/Supply Chain Project/CartIQ/data/raw/order_products_prior.csv")

# %%
data_2.shape
# Out:
# (32434489, 4)

# %%
data.order_id.nunique()
# Out:
# 3421083

# %%
data3 = pd.read_csv("/Users/abhijeetsinghparihar/Desktop/Projects/Supply Chain Project/CartIQ/data/processed/master_orders.csv")

# %%
data3.shape
# Out:
# (2019713, 11)

# %%
data3.order_id.nunique()
# Out:
# 200000

# %%
data_2.columns
# Out:
# Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='str')

# %%
data_2.product_id.nunique()
# Out:
# 49677

# %%
data3.product_id.nunique()
# Out:
# 40649
